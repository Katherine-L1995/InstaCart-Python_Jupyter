# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
file_path = r'C:\Users\lecce\OneDrive\Achievement 4 - Python\02 Data\og data'

# %%
import pandas as pd

# Provide the correct path to the CSV file
dp_orders = pd.read_csv(r'C:\Users\lecce\OneDrive\Achievement 4 - Python\02 Data\og data\orders.csv')

# %%
dp_orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
dp_orders.drop(columns = ['eval_set'])
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
dp_orders.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)

# %%
dp_orders.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
dp_orders.drop(columns = ['eval_set'])
# Out:
#          order_id  user_id  order_number  orders_day_of_week  \
# 0         2539329        1             1                   2
# 1         2398795        1             2                   3
# 2          473747        1             3                   3
# 3         2254736        1             4                   4
# 4          431534        1             5                   4
# ...           ...      ...           ...                 ...
# 3421078   2266710   206209            10                   5
# 3421079   1854736   206209            11                   4
# 3421080    626363   206209            12                   1
# 3421081   2977660   206209            13                   1
# 3421082    272231   206209            14                   6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %%
dp_orders['order_id'] = dp_orders['order_id'].astype('str')

# %%
dp_orders_2 = dp_orders.drop(columns = ['days_since_prior_order'])

# %%
print(dp_orders_2)
# Out:
#         order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0        2539329        1    prior             1                   2
# 1        2398795        1    prior             2                   3
# 2         473747        1    prior             3                   3
# 3        2254736        1    prior             4                   4
# 4         431534        1    prior             5                   4
# ...          ...      ...      ...           ...                 ...
# 3421078  2266710   206209    prior            10                   5
# 3421079  1854736   206209    prior            11                   4
# 3421080   626363   206209    prior            12                   1
# 3421081  2977660   206209    prior            13                   1
# 3421082   272231   206209    train            14                   6
#
#          order_hour_of_day
# 0                        8
# 1                        7
# 2                       12
# ...

# %%
dp_orders['orders_hour_of_day'] = dp_orders['order_hour_of_day'].astype('str')

# %%
dp_orders['orders_hour_of_day'].dtype
# Out:
# dtype('O')

# %%
order_counts = dp_orders.groupby('order_hour_of_day').size()

# %%
print("\nOrder counts per hour:")
print(order_counts)
# Out:
# Order counts per hour:
# order_hour_of_day
# 0      22758
# 1      12398
# 2       7539
# 3       5474
# 4       5527
# 5       9569
# 6      30529
# 7      91868
# 8     178201
# 9     257812
# 10    288418
# 11    284728
# 12    272841
# 13    277999
# 14    283042
# 15    283639
# 16    272553
# 17    228795
# 18    182912
# 19    140569
# 20    104292
# 21     78109
# 22     61468
# 23     40043
# dtype: int64

# %%
busiest_hour = order_counts.idxmax()
max_orders = order_counts.max()

# %%
print(f"\nBusiest hour of the day: {busiest_hour} with {max_orders} orders")
# Out:
# Busiest hour of the day: 10 with 288418 orders

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
file_path = r'C:\Users\lecce\OneDrive\Achievement 4 - Python\02 Data\og data'

# %%
import pandas as pd

# Provide the correct path to the CSV file
dp_products = pd.read_csv(r'C:\Users\lecce\OneDrive\Achievement 4 - Python\02 Data\og data\products.csv')

# %%
dp_products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
dp_products_t = dp_products.T

# %%
dp_products_t
# Out:
#                                     0                 1      \
# product_id                              1                 2
# product_name   Chocolate Sandwich Cookies  All-Seasons Salt
# aisle_id                               61               104
# department_id                          19                13
# prices                                5.8               9.3
#
#                                               2      \
# product_id                                        3
# product_name   Robust Golden Unsweetened Oolong Tea
# aisle_id                                         94
# department_id                                     7
# prices                                          4.5
#
#                                                            3      \
# product_id                                                     4
# product_name   Smart Ones Classic Favorites Mini Rigatoni Wit...
# aisle_id                                                      38
# ...

# %%
dp_products_t.reset_index()
# Out:
#            index                           0                 1  \
# 0     product_id                           1                 2
# 1   product_name  Chocolate Sandwich Cookies  All-Seasons Salt
# 2       aisle_id                          61               104
# 3  department_id                          19                13
# 4         prices                         5.8               9.3
#
#                                       2  \
# 0                                     3
# 1  Robust Golden Unsweetened Oolong Tea
# 2                                    94
# 3                                     7
# 4                                   4.5
#
#                                                    3  \
# 0                                                  4
# 1  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 2                                                 38
# 3                                                  1
# 4                                               10.5
#
# ...

# %%
new_header = dp_products_t.iloc[0]

# %%
dp_products_t_new = dp_products_t[1:]

# %%
dp_products_t_new
# Out:
#                                     0                 1      \
# product_name   Chocolate Sandwich Cookies  All-Seasons Salt
# aisle_id                               61               104
# department_id                          19                13
# prices                                5.8               9.3
#
#                                               2      \
# product_name   Robust Golden Unsweetened Oolong Tea
# aisle_id                                         94
# department_id                                     7
# prices                                          4.5
#
#                                                            3      \
# product_name   Smart Ones Classic Favorites Mini Rigatoni Wit...
# aisle_id                                                      38
# department_id                                                  1
# prices                                                      10.5
#
#                                    4             5      \
# ...

# %%
dp_products_t_new.columns = new_header

# %%
data_dict_products = dp_products_t_new.to_dict('index')
# Out:
# C:\Users\lecce\AppData\Local\Temp\ipykernel_35732\121699821.py:1: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   data_dict_products = dp_products_t_new.to_dict('index')

# %%
data_dict_products
# Out:
# {'product_name': {1: 'Chocolate Sandwich Cookies',
#   2: 'All-Seasons Salt',
#   3: 'Robust Golden Unsweetened Oolong Tea',
#   4: 'Smart Ones Classic Favorites Mini Rigatoni With Vodka Cream Sauce',
#   5: 'Green Chile Anytime Sauce',
#   6: 'Dry Nose Oil',
#   7: 'Pure Coconut Water With Orange',
#   8: "Cut Russet Potatoes Steam N' Mash",
#   9: 'Light Strawberry Blueberry Yogurt',
#   10: 'Sparkling Orange Juice & Prickly Pear Beverage',
#   11: 'Peach Mango Juice',
#   12: 'Chocolate Fudge Layer Cake',
#   13: 'Saline Nasal Mist',
#   14: 'Fresh Scent Dishwasher Cleaner',
#   15: 'Overnight Diapers Size 6',
#   16: 'Mint Chocolate Flavored Syrup',
#   17: 'Rendered Duck Fat',
#   18: 'Pizza for One Suprema  Frozen Pizza',
#   19: 'Gluten Free Quinoa Three Cheese & Mushroom Blend',
#   20: 'Pomegranate Cranberry & Aloe Vera Enrich Drink',
#   21: 'Small & Medium Dental Dog Treats',
#   22: 'Fresh Breath Oral Rinse Mild Mint',
#   23: 'Organic Turkey Burgers',
# ...

# %%
file_path
# Out:
# 'C:\\Users\\lecce\\OneDrive\\Achievement 4 - Python\\02 Data\\og data'

# %%
dp_breakfast =  dp_products[dp_products['department_id']==14]

# %%
dp_products['department_id']==14
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49688    False
# 49689    False
# 49690    False
# 49691    False
# 49692    False
# Name: department_id, Length: 49693, dtype: bool

# %%
dp_products[dp_products['department_id']==14]
# Out:
#        product_id                                       product_name  \
# 27             28                                  Wheat Chex Cereal
# 33             34                                                NaN
# 67             68                            Pancake Mix, Buttermilk
# 89             90                                       Smorz Cereal
# 210           211   Gluten Free Organic Cereal Coconut Maple Vanilla
# ...           ...                                                ...
# 49330       49326                            Cereal Variety Fun Pack
# 49395       49391            Light and Fluffy Buttermilk Pancake Mix
# 49547       49543                          Chocolate Cheerios Cereal
# 49637       49633               Shake 'N Pour Buttermilk Pancake Mix
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
#
#        aisle_id  department_id  prices
# 27          121             14    10.1
# 33          121             14    12.2
# ...

# %%
dp_breakfast = dp_products[dp_products['department_id']==14]

# %%
dp_breakfast.head()
# Out:
#      product_id                                      product_name  aisle_id  \
# 27           28                                 Wheat Chex Cereal       121
# 33           34                                               NaN       121
# 67           68                           Pancake Mix, Buttermilk       130
# 89           90                                      Smorz Cereal       121
# 210         211  Gluten Free Organic Cereal Coconut Maple Vanilla       130
#
#      department_id  prices
# 27              14    10.1
# 33              14    12.2
# 67              14    13.7
# 89              14     3.9
# 210             14     3.6

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
file_path = r'C:\Users\lecce\Downloads\4.4_departments.zip'

# %%
import pandas as pd

# Provide the correct path to the CSV file
dp_depar = pd.read_csv(r'C:\Users\lecce\OneDrive\Desktop\Achievement 4 - Python\02 Data\og data\departments.csv')

# %%
dp_depar.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
df_dep_t = dp_depar.T

# %%
df_dep_t
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
new_header = df_dep_t.iloc[0]

# %%
df_dep_t_new = df_dep_t[1:]

# %%
df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
df_dep_t_new.columns = new_header

# %%
data_dict = df_dep_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
path = r'C:\Users\lecce\OneDrive\Achievement 4 - Python\02 Data\prepared data'

# %%
dp_orders.to_csv(os.path.join(path, 'orders_wrangled.csv'))

# %%
df_dep_t_new.to_csv(os.path.join(path, 'departments_wrangled.csv'))
